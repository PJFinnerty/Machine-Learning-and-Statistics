# %% [markdown]
# ## Reference: https://www.marsja.se/four-ways-to-conduct-one-way-anovas-using-python/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_wine
# Import train and test split
from sklearn.model_selection import train_test_split

# Improt preprocessing module
from sklearn import preprocessing

# Import Random Forest
from sklearn.ensemble import RandomForestRegressor

# Import cross-validation tools
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# Import metrics for model performance
from sklearn.metrics import mean_squared_error, r2_score

# Import module for storing arrays
import joblib

from sklearn.neighbors import KNeighborsClassifier

from scipy import stats as ss

import collections as co

# Specials.
import scipy.special as spec

# %%
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('Diet.csv')

# %%
df
# Out:
#     Person gender  Age  Height  pre.weight  Diet  weight6weeks
# 0       25    NaN   41     171          60     2          60.0
# 1       26    NaN   32     174         103     2         103.0
# 2        1      0   22     159          58     1          54.2
# 3        2      0   46     192          60     1          54.0
# 4        3      0   55     170          64     1          63.3
# 5        4      0   33     171          64     1          61.1
# 6        5      0   50     170          65     1          62.2
# 7        6      0   50     201          66     1          64.0
# 8        7      0   37     174          67     1          65.0
# 9        8      0   28     176          69     1          60.5
# 10       9      0   28     165          70     1          68.1
# 11      10      0   45     165          70     1          66.9
# 12      11      0   60     173          72     1          70.5
# 13      12      0   48     156          72     1          69.0
# 14      13      0   41     163          72     1          68.4
# 15      14      0   37     167          82     1          81.1
# 16      27      0   44     174          58     2          60.1
# 17      28      0   37     172          58     2          56.0
# 18      29      0   41     165          59     2          57.3
# 19      30      0   43     171          61     2          56.7
# 20      31      0   20     169          62     2          55.0
# 21      32      0   51     174          63     2          62.4
# 22      33      0   31     163          63     2          60.3
# 23      34      0   54     173          63     2          59.4
# 24      35      0   50     166          65     2          62.0
# 25      36      0   48     163          66     2          64.0
# 26      37      0   16     165          68     2          63.8
# 27      38      0   37     167          68     2          63.3
# 28      39      0   30     161          76     2          72.7
# 29      40      0   29     169          77     2          77.5
# 30      52      0   51     165          60     3          53.0
# 31      53      0   35     169          62     3          56.4
# 32      54      0   21     159          64     3          60.6
# 33      55      0   22     169          65     3          58.2
# 34      56      0   36     160          66     3          58.2
# 35      57      0   20     169          67     3          61.6
# 36      58      0   35     163          67     3          60.2
# 37      59      0   45     155          69     3          61.8
# 38      60      0   58     141          70     3          63.0
# 39      61      0   37     170          70     3          62.7
# 40      62      0   31     170          72     3          71.1
# 41      63      0   35     171          72     3          64.4
# 42      64      0   56     171          73     3          68.9
# 43      65      0   48     153          75     3          68.7
# 44      66      0   41     157          76     3          71.0
# 45      15      1   39     168          71     1          71.6
# 46      16      1   31     158          72     1          70.9
# 47      17      1   40     173          74     1          69.5
# 48      18      1   50     160          78     1          73.9
# 49      19      1   43     162          80     1          71.0
# 50      20      1   25     165          80     1          77.6
# 51      21      1   52     177          83     1          79.1
# 52      22      1   42     166          85     1          81.5
# 53      23      1   39     166          87     1          81.9
# 54      24      1   40     190          88     1          84.5
# 55      41      1   51     191          71     2          66.8
# 56      42      1   38     199          75     2          72.6
# 57      43      1   54     196          75     2          69.2
# 58      44      1   33     190          76     2          72.5
# 59      45      1   45     160          78     2          72.7
# 60      46      1   37     194          78     2          76.3
# 61      47      1   44     163          79     2          73.6
# 62      48      1   40     171          79     2          72.9
# 63      49      1   37     198          79     2          71.1
# 64      50      1   39     180          80     2          81.4
# 65      51      1   31     182          80     2          75.7
# 66      67      1   36     155          71     3          68.5
# 67      68      1   47     179          73     3          72.1
# 68      69      1   29     166          76     3          72.5
# 69      70      1   37     173          78     3          77.5
# 70      71      1   31     177          78     3          75.2
# 71      72      1   26     179          78     3          69.4
# 72      73      1   40     179          79     3          74.5
# 73      74      1   35     183          83     3          80.2
# 74      75      1   49     177          84     3          79.9
# 75      76      1   28     164          85     3          79.7
# 76      77      1   40     167          87     3          77.8
# 77      78      1   51     175          88     3          81.9

# %% [markdown]
# ## Create 'WeightLost' Column

# %%
#weightLost_df = df

# %%
df['weightLost'] = df['pre.weight'] - df['weight6weeks']

# %%
df
# Out:
#     Person gender  Age  Height  pre.weight  Diet  weight6weeks  weightLost
# 0       25    NaN   41     171          60     2          60.0         0.0
# 1       26    NaN   32     174         103     2         103.0         0.0
# 2        1      0   22     159          58     1          54.2         3.8
# 3        2      0   46     192          60     1          54.0         6.0
# 4        3      0   55     170          64     1          63.3         0.7
# 5        4      0   33     171          64     1          61.1         2.9
# 6        5      0   50     170          65     1          62.2         2.8
# 7        6      0   50     201          66     1          64.0         2.0
# 8        7      0   37     174          67     1          65.0         2.0
# 9        8      0   28     176          69     1          60.5         8.5
# 10       9      0   28     165          70     1          68.1         1.9
# 11      10      0   45     165          70     1          66.9         3.1
# 12      11      0   60     173          72     1          70.5         1.5
# 13      12      0   48     156          72     1          69.0         3.0
# 14      13      0   41     163          72     1          68.4         3.6
# 15      14      0   37     167          82     1          81.1         0.9
# 16      27      0   44     174          58     2          60.1        -2.1
# 17      28      0   37     172          58     2          56.0         2.0
# 18      29      0   41     165          59     2          57.3         1.7
# 19      30      0   43     171          61     2          56.7         4.3
# 20      31      0   20     169          62     2          55.0         7.0
# 21      32      0   51     174          63     2          62.4         0.6
# 22      33      0   31     163          63     2          60.3         2.7
# 23      34      0   54     173          63     2          59.4         3.6
# 24      35      0   50     166          65     2          62.0         3.0
# 25      36      0   48     163          66     2          64.0         2.0
# 26      37      0   16     165          68     2          63.8         4.2
# 27      38      0   37     167          68     2          63.3         4.7
# 28      39      0   30     161          76     2          72.7         3.3
# 29      40      0   29     169          77     2          77.5        -0.5
# 30      52      0   51     165          60     3          53.0         7.0
# 31      53      0   35     169          62     3          56.4         5.6
# 32      54      0   21     159          64     3          60.6         3.4
# 33      55      0   22     169          65     3          58.2         6.8
# 34      56      0   36     160          66     3          58.2         7.8
# 35      57      0   20     169          67     3          61.6         5.4
# 36      58      0   35     163          67     3          60.2         6.8
# 37      59      0   45     155          69     3          61.8         7.2
# 38      60      0   58     141          70     3          63.0         7.0
# 39      61      0   37     170          70     3          62.7         7.3
# 40      62      0   31     170          72     3          71.1         0.9
# 41      63      0   35     171          72     3          64.4         7.6
# 42      64      0   56     171          73     3          68.9         4.1
# 43      65      0   48     153          75     3          68.7         6.3
# 44      66      0   41     157          76     3          71.0         5.0
# 45      15      1   39     168          71     1          71.6        -0.6
# 46      16      1   31     158          72     1          70.9         1.1
# 47      17      1   40     173          74     1          69.5         4.5
# 48      18      1   50     160          78     1          73.9         4.1
# 49      19      1   43     162          80     1          71.0         9.0
# 50      20      1   25     165          80     1          77.6         2.4
# 51      21      1   52     177          83     1          79.1         3.9
# 52      22      1   42     166          85     1          81.5         3.5
# 53      23      1   39     166          87     1          81.9         5.1
# 54      24      1   40     190          88     1          84.5         3.5
# 55      41      1   51     191          71     2          66.8         4.2
# 56      42      1   38     199          75     2          72.6         2.4
# 57      43      1   54     196          75     2          69.2         5.8
# 58      44      1   33     190          76     2          72.5         3.5
# 59      45      1   45     160          78     2          72.7         5.3
# 60      46      1   37     194          78     2          76.3         1.7
# 61      47      1   44     163          79     2          73.6         5.4
# 62      48      1   40     171          79     2          72.9         6.1
# 63      49      1   37     198          79     2          71.1         7.9
# 64      50      1   39     180          80     2          81.4        -1.4
# 65      51      1   31     182          80     2          75.7         4.3
# 66      67      1   36     155          71     3          68.5         2.5
# 67      68      1   47     179          73     3          72.1         0.9
# 68      69      1   29     166          76     3          72.5         3.5
# 69      70      1   37     173          78     3          77.5         0.5
# 70      71      1   31     177          78     3          75.2         2.8
# 71      72      1   26     179          78     3          69.4         8.6
# 72      73      1   40     179          79     3          74.5         4.5
# 73      74      1   35     183          83     3          80.2         2.8
# 74      75      1   49     177          84     3          79.9         4.1
# 75      76      1   28     164          85     3          79.7         5.3
# 76      77      1   40     167          87     3          77.8         9.2
# 77      78      1   51     175          88     3          81.9         6.1

# %%
#Run once:
df['Diet'] = df['Diet'] - 1

# %%
df
# Out:
#     Person gender  Age  Height  pre.weight  Diet  weight6weeks  weightLost
# 0       25    NaN   41     171          60     1          60.0         0.0
# 1       26    NaN   32     174         103     1         103.0         0.0
# 2        1      0   22     159          58     0          54.2         3.8
# 3        2      0   46     192          60     0          54.0         6.0
# 4        3      0   55     170          64     0          63.3         0.7
# 5        4      0   33     171          64     0          61.1         2.9
# 6        5      0   50     170          65     0          62.2         2.8
# 7        6      0   50     201          66     0          64.0         2.0
# 8        7      0   37     174          67     0          65.0         2.0
# 9        8      0   28     176          69     0          60.5         8.5
# 10       9      0   28     165          70     0          68.1         1.9
# 11      10      0   45     165          70     0          66.9         3.1
# 12      11      0   60     173          72     0          70.5         1.5
# 13      12      0   48     156          72     0          69.0         3.0
# 14      13      0   41     163          72     0          68.4         3.6
# 15      14      0   37     167          82     0          81.1         0.9
# 16      27      0   44     174          58     1          60.1        -2.1
# 17      28      0   37     172          58     1          56.0         2.0
# 18      29      0   41     165          59     1          57.3         1.7
# 19      30      0   43     171          61     1          56.7         4.3
# 20      31      0   20     169          62     1          55.0         7.0
# 21      32      0   51     174          63     1          62.4         0.6
# 22      33      0   31     163          63     1          60.3         2.7
# 23      34      0   54     173          63     1          59.4         3.6
# 24      35      0   50     166          65     1          62.0         3.0
# 25      36      0   48     163          66     1          64.0         2.0
# 26      37      0   16     165          68     1          63.8         4.2
# 27      38      0   37     167          68     1          63.3         4.7
# 28      39      0   30     161          76     1          72.7         3.3
# 29      40      0   29     169          77     1          77.5        -0.5
# 30      52      0   51     165          60     2          53.0         7.0
# 31      53      0   35     169          62     2          56.4         5.6
# 32      54      0   21     159          64     2          60.6         3.4
# 33      55      0   22     169          65     2          58.2         6.8
# 34      56      0   36     160          66     2          58.2         7.8
# 35      57      0   20     169          67     2          61.6         5.4
# 36      58      0   35     163          67     2          60.2         6.8
# 37      59      0   45     155          69     2          61.8         7.2
# 38      60      0   58     141          70     2          63.0         7.0
# 39      61      0   37     170          70     2          62.7         7.3
# 40      62      0   31     170          72     2          71.1         0.9
# 41      63      0   35     171          72     2          64.4         7.6
# 42      64      0   56     171          73     2          68.9         4.1
# 43      65      0   48     153          75     2          68.7         6.3
# 44      66      0   41     157          76     2          71.0         5.0
# 45      15      1   39     168          71     0          71.6        -0.6
# 46      16      1   31     158          72     0          70.9         1.1
# 47      17      1   40     173          74     0          69.5         4.5
# 48      18      1   50     160          78     0          73.9         4.1
# 49      19      1   43     162          80     0          71.0         9.0
# 50      20      1   25     165          80     0          77.6         2.4
# 51      21      1   52     177          83     0          79.1         3.9
# 52      22      1   42     166          85     0          81.5         3.5
# 53      23      1   39     166          87     0          81.9         5.1
# 54      24      1   40     190          88     0          84.5         3.5
# 55      41      1   51     191          71     1          66.8         4.2
# 56      42      1   38     199          75     1          72.6         2.4
# 57      43      1   54     196          75     1          69.2         5.8
# 58      44      1   33     190          76     1          72.5         3.5
# 59      45      1   45     160          78     1          72.7         5.3
# 60      46      1   37     194          78     1          76.3         1.7
# 61      47      1   44     163          79     1          73.6         5.4
# 62      48      1   40     171          79     1          72.9         6.1
# 63      49      1   37     198          79     1          71.1         7.9
# 64      50      1   39     180          80     1          81.4        -1.4
# 65      51      1   31     182          80     1          75.7         4.3
# 66      67      1   36     155          71     2          68.5         2.5
# 67      68      1   47     179          73     2          72.1         0.9
# 68      69      1   29     166          76     2          72.5         3.5
# 69      70      1   37     173          78     2          77.5         0.5
# 70      71      1   31     177          78     2          75.2         2.8
# 71      72      1   26     179          78     2          69.4         8.6
# 72      73      1   40     179          79     2          74.5         4.5
# 73      74      1   35     183          83     2          80.2         2.8
# 74      75      1   49     177          84     2          79.9         4.1
# 75      76      1   28     164          85     2          79.7         5.3
# 76      77      1   40     167          87     2          77.8         9.2
# 77      78      1   51     175          88     2          81.9         6.1

# %% [markdown]
# ## Assumption 1: Dependent Variable

# %% [markdown]
# ### Dependent: Weightost

# %%
weightLost = df['weightLost']

# %% [markdown]
# ## Assumption 2: Independent Variable

# %% [markdown]
# ### 1: Diet

# %%
Diet = df['Diet']

# %% [markdown]
# ### 2: gender

# %%
gender = df['gender']

# %% [markdown]
# ## Assumption 4: Outliers

# %%
sns.boxplot(x=Diet, y=weightLost)

# %%
weightLost.describe()
# Out:
# count    78.000000
# mean      3.844872
# std       2.551478
# min      -2.100000
# 25%       2.000000
# 50%       3.600000
# 75%       5.550000
# max       9.200000
# Name: weightLost, dtype: float64

# %% [markdown]
# ## Assumption 5: Normality

# %%
from seaborn import displot

# %%
sns.scatterplot(df['gender'], weightLost, hue=df['Diet'])
# Out:
# c:\users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.FacetGrid(df,hue='Diet',height=5.5).map(sns.distplot,'weightLost', kde=True).add_legend()
# Out:
# c:\users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
diet_one = weightLost[Diet==0]
diet_two = weightLost[Diet==1]
diet_three = weightLost[Diet==2]

# %% [markdown]
# ### Run Shapiro Wilks Test

# %%
ss.shapiro(diet_one)
# Out:
# ShapiroResult(statistic=0.9255314469337463, pvalue=0.07748671621084213)

# %%
ss.shapiro(diet_two)
# Out:
# ShapiroResult(statistic=0.9855913519859314, pvalue=0.961176335811615)

# %%
ss.shapiro(diet_three)
# Out:
# ShapiroResult(statistic=0.9601252675056458, pvalue=0.37203603982925415)

# %% [markdown]
# #### All 3 distributions for the diets in terms of the dependent variable 'weightLost', have a p-value greater than 0.05. As such, the evidence suggests that all 3 groups are normally distributed

# %% [markdown]
# ## Assumption 6: Homogeneity of Variances

# %% [markdown]
# ### Levene's Test for Homogeneity - using Levene() from Scipy-stats

# %%
ss.levene(
    weightLost[Diet==0],
    weightLost[Diet==1],
    weightLost[Diet==2]
)
# Out:
# LeveneResult(statistic=0.6256665777896312, pvalue=0.5376731304274011)

# %% [markdown]
# ### When studying the homogeneity of 'weightLost' amongst the three categories of Diets above are showing a p-value greater than 0.05.
#
# ### Infact, it is much greater at *0.53*.

# %% [markdown]
# ***
#
# # One-way Anova
#
# <br>

# %%
ss.f_oneway(
    weightLost[Diet==0],
    weightLost[Diet==1],
    weightLost[Diet==2]
    )
# Out:
# F_onewayResult(statistic=6.197447453165349, pvalue=0.0032290142385893524)

# %% [markdown]
# ### As we see above, the p-value of 0.003 (*lower than 0.05*) suggests that the mean-values for the three diets in the independent variable are different.

# %% [markdown]
# ***
#
# ## Unequal Variances Welch Anova
#
# <br>

# %%
def welch_anova_np(*args, var_equal=False):
    # https://svn.r-project.org/R/trunk/src/library/stats/R/oneway.test.R
    # translated from R Welch ANOVA (not assuming equal variance)

    F_onewayResult = co.namedtuple('F_onewayResult', ('statistic', 'pvalue'))

    args = [np.asarray(arg, dtype=float) for arg in args]
    k = len(args)
    ni = np.array([len(arg) for arg in args])
    mi = np.array([np.mean(arg) for arg in args])
    vi = np.array([np.var(arg,ddof=1) for arg in args])
    wi = ni/vi

    tmp =sum((1-wi/sum(wi))**2 / (ni-1))
    tmp /= (k**2 -1)

    dfbn = k - 1
    dfwn = 1 / (3 * tmp)

    m = sum(mi*wi) / sum(wi)
    f = sum(wi * (mi - m)**2) /((dfbn) * (1 + 2 * (dfbn - 1) * tmp))
    prob = spec.fdtrc(dfbn, dfwn, f)   # equivalent to stats.f.sf
    return F_onewayResult(f, prob)

# %%
# Perform the test.
welch_anova_np(
    weightLost[Diet==0],
    weightLost[Diet==1],
    weightLost[Diet==2]
)
# Out:
# F_onewayResult(statistic=6.04665295066696, pvalue=0.004452841593741384)

# %% [markdown]
# ### The p-value obtained from this Anova test of different variances is 0.00445 - this is significantly below the threshold of 0.05.
#
# ### The conclusion here is that the mean-weight lost by people who tried out diets 1, 2 and 3 over 6 weeks, **are different.**
