# %% [markdown]
# ## Reference: https://www.marsja.se/four-ways-to-conduct-one-way-anovas-using-python/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_wine
# Import train and test split\
from sklearn.model_selection import train_test_split

# Improt preprocessing module
from sklearn import preprocessing

# Import Random Forest
from sklearn.ensemble import RandomForestRegressor

# Import cross-validation tools
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# Import metrics for model performance
from sklearn.metrics import mean_squared_error, r2_score

# Import module for storing arrays
import joblib

from sklearn.neighbors import KNeighborsClassifier

from scipy import stats as ss

import collections as co

# Specials.
import scipy.special as spec

# %%
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('Diet.csv')

# %%
df
# Out:
#     Person gender  Age  Height  pre.weight  Diet  weight6weeks
# 0       25    NaN   41     171          60     2          60.0
# 1       26    NaN   32     174         103     2         103.0
# 2        1      0   22     159          58     1          54.2
# 3        2      0   46     192          60     1          54.0
# 4        3      0   55     170          64     1          63.3
# 5        4      0   33     171          64     1          61.1
# 6        5      0   50     170          65     1          62.2
# 7        6      0   50     201          66     1          64.0
# 8        7      0   37     174          67     1          65.0
# 9        8      0   28     176          69     1          60.5
# 10       9      0   28     165          70     1          68.1
# 11      10      0   45     165          70     1          66.9
# 12      11      0   60     173          72     1          70.5
# 13      12      0   48     156          72     1          69.0
# 14      13      0   41     163          72     1          68.4
# 15      14      0   37     167          82     1          81.1
# 16      27      0   44     174          58     2          60.1
# 17      28      0   37     172          58     2          56.0
# 18      29      0   41     165          59     2          57.3
# 19      30      0   43     171          61     2          56.7
# 20      31      0   20     169          62     2          55.0
# 21      32      0   51     174          63     2          62.4
# 22      33      0   31     163          63     2          60.3
# 23      34      0   54     173          63     2          59.4
# 24      35      0   50     166          65     2          62.0
# 25      36      0   48     163          66     2          64.0
# 26      37      0   16     165          68     2          63.8
# 27      38      0   37     167          68     2          63.3
# 28      39      0   30     161          76     2          72.7
# 29      40      0   29     169          77     2          77.5
# 30      52      0   51     165          60     3          53.0
# 31      53      0   35     169          62     3          56.4
# 32      54      0   21     159          64     3          60.6
# 33      55      0   22     169          65     3          58.2
# 34      56      0   36     160          66     3          58.2
# 35      57      0   20     169          67     3          61.6
# 36      58      0   35     163          67     3          60.2
# 37      59      0   45     155          69     3          61.8
# 38      60      0   58     141          70     3          63.0
# 39      61      0   37     170          70     3          62.7
# 40      62      0   31     170          72     3          71.1
# 41      63      0   35     171          72     3          64.4
# 42      64      0   56     171          73     3          68.9
# 43      65      0   48     153          75     3          68.7
# 44      66      0   41     157          76     3          71.0
# 45      15      1   39     168          71     1          71.6
# 46      16      1   31     158          72     1          70.9
# 47      17      1   40     173          74     1          69.5
# 48      18      1   50     160          78     1          73.9
# 49      19      1   43     162          80     1          71.0
# 50      20      1   25     165          80     1          77.6
# 51      21      1   52     177          83     1          79.1
# 52      22      1   42     166          85     1          81.5
# 53      23      1   39     166          87     1          81.9
# 54      24      1   40     190          88     1          84.5
# 55      41      1   51     191          71     2          66.8
# 56      42      1   38     199          75     2          72.6
# 57      43      1   54     196          75     2          69.2
# 58      44      1   33     190          76     2          72.5
# 59      45      1   45     160          78     2          72.7
# 60      46      1   37     194          78     2          76.3
# 61      47      1   44     163          79     2          73.6
# 62      48      1   40     171          79     2          72.9
# 63      49      1   37     198          79     2          71.1
# 64      50      1   39     180          80     2          81.4
# 65      51      1   31     182          80     2          75.7
# 66      67      1   36     155          71     3          68.5
# 67      68      1   47     179          73     3          72.1
# 68      69      1   29     166          76     3          72.5
# 69      70      1   37     173          78     3          77.5
# 70      71      1   31     177          78     3          75.2
# 71      72      1   26     179          78     3          69.4
# 72      73      1   40     179          79     3          74.5
# 73      74      1   35     183          83     3          80.2
# 74      75      1   49     177          84     3          79.9
# 75      76      1   28     164          85     3          79.7
# 76      77      1   40     167          87     3          77.8
# 77      78      1   51     175          88     3          81.9

# %% [markdown]
# ## Create 'BMI_change' Column

# %%
#BMI_change_df = df

# %%
df['BMI_start'] = df["pre.weight"] / (df["Height"] / 100)**2
df["BMI_end"] = df["weight6weeks"] / (df["Height"] / 100)**2
df["BMI_change"] = df['BMI_start'] - df["BMI_end"]

# %%
df
# Out:
#     Person gender  Age  Height  pre.weight  Diet  weight6weeks  BMI_start  \
# 0       25    NaN   41     171          60     2          60.0  20.519134
# 1       26    NaN   32     174         103     2         103.0  34.020346
# 2        1      0   22     159          58     1          54.2  22.942130
# 3        2      0   46     192          60     1          54.0  16.276042
# 4        3      0   55     170          64     1          63.3  22.145329
# 5        4      0   33     171          64     1          61.1  21.887076
# 6        5      0   50     170          65     1          62.2  22.491349
# 7        6      0   50     201          66     1          64.0  16.336229
# 8        7      0   37     174          67     1          65.0  22.129740
# 9        8      0   28     176          69     1          60.5  22.275310
# 10       9      0   28     165          70     1          68.1  25.711662
# 11      10      0   45     165          70     1          66.9  25.711662
# 12      11      0   60     173          72     1          70.5  24.056935
# 13      12      0   48     156          72     1          69.0  29.585799
# 14      13      0   41     163          72     1          68.4  27.099251
# 15      14      0   37     167          82     1          81.1  29.402273
# 16      27      0   44     174          58     2          60.1  19.157088
# 17      28      0   37     172          58     2          56.0  19.605192
# 18      29      0   41     165          59     2          57.3  21.671258
# 19      30      0   43     171          61     2          56.7  20.861120
# 20      31      0   20     169          62     2          55.0  21.707923
# 21      32      0   51     174          63     2          62.4  20.808561
# 22      33      0   31     163          63     2          60.3  23.711845
# 23      34      0   54     173          63     2          59.4  21.049818
# 24      35      0   50     166          65     2          62.0  23.588329
# 25      36      0   48     163          66     2          64.0  24.840980
# 26      37      0   16     165          68     2          63.8  24.977043
# 27      38      0   37     167          68     2          63.3  24.382373
# 28      39      0   30     161          76     2          72.7  29.319856
# 29      40      0   29     169          77     2          77.5  26.959840
# 30      52      0   51     165          60     3          53.0  22.038567
# 31      53      0   35     169          62     3          56.4  21.707923
# 32      54      0   21     159          64     3          60.6  25.315454
# 33      55      0   22     169          65     3          58.2  22.758307
# 34      56      0   36     160          66     3          58.2  25.781250
# 35      57      0   20     169          67     3          61.6  23.458562
# 16  19.850707   -0.693619
# 17  18.929151    0.676041
# 18  21.046832    0.624426
# 19  19.390582    1.470538
# 20  19.257029    2.450895
# 21  20.610384    0.198177
# 22  22.695623    1.016222
# 23  19.846971    1.202847
# 24  22.499637    1.088692
# 25  24.088223    0.752757
# 26  23.434343    1.542700
# 27  22.697121    1.685252
# 28  28.046757    1.273099
# 29  27.134904   -0.175064
# 30  19.467401    2.571166
# 31  19.747208    1.960716
# 32  23.970571    1.344884
# 33  20.377438    2.380869
# 34  22.734375    3.046875
# 35  21.567872    1.890690
# 36  22.657985    2.559374
# 37  25.723205    2.996878
# 38  31.688547    3.520950
# 39  21.695502    2.525952
# 40  24.602076    0.311419
# 41  22.023871    2.599090
# 42  23.562806    1.402141
# 43  29.347687    2.691273
# 44  28.804414    2.028480
# 45  25.368481   -0.212585
# 46  28.400897    0.440635
# 47  23.221625    1.503558
# 48  28.867187    1.601562
# 49  27.053803    3.429355
# 50  28.503214    0.881543
# 51  25.248173    1.244853
# 52  29.576136    1.270141
# 53  29.721295    1.850777
# 54  23.407202    0.969529
# 55  18.310902    1.151284
# 56  18.332870    0.606045
# 57  18.013328    1.509788
# 58  20.083102    0.969529
# 59  28.398437    2.070312
# 60  20.273143    0.451695
# 61  27.701457    2.032444
# 62  24.930748    2.086112
# 63  18.135904    2.015100
# 64  25.123457   -0.432099
# 65  22.853520    1.298152
# 66  28.511967    1.040583
# 67  22.502419    0.280890
# 68  26.310060    1.270141
# 69  25.894617    0.167062
# 70  24.003320    0.893741
# 71  21.659748    2.684061
# 72  23.251459    1.404451
# 73  23.948162    0.836095
# 74  25.503527    1.308692
# 75  29.632659    1.970553
# 76  27.896303    3.298792
# 77  26.742857    1.991837

# %%
df.to_csv('diet_BMI_incl.csv')

# %% [markdown]
# ## Assumption 1: Dependent Variable

# %% [markdown]
# ### Dependent: Weightoss

# %%
BMI_change = df['BMI_change']

# %% [markdown]
# ## Assumption 2: Independent Variable

# %% [markdown]
# ### 1: Diet

# %%
Diet = df['Diet']

# %% [markdown]
# ### 2: gender

# %%
gender = df['gender']

# %% [markdown]
# ## Assumption 4: Outliers

# %%
sns.boxplot(x=Diet, y=BMI_change)

# %%
BMI_change.describe()
# Out:
# count    78.000000
# mean      1.350125
# std       0.934202
# min      -0.693619
# 25%       0.681503
# 50%       1.271620
# 75%       1.986516
# max       3.520950
# Name: BMI_change, dtype: float64

# %%
diet_1 = df[df["Diet"] == 1]["BMI_change"].to_list()
diet_2 = df[df["Diet"] == 2]["BMI_change"].to_list()
diet_3 = df[df["Diet"] == 3]["BMI_change"].to_list()

# %%
mean = df.BMI_change.mean()
mean
# Out:
# 1.3501245872689778

# %% [markdown]
# ## Assumption 5: Normality

# %%
from seaborn import displot

# %%
sns.scatterplot(df['gender'], BMI_change, hue=df['Diet'])
# Out:
# c:\users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.FacetGrid(df,hue='Diet',height=5.5).map(sns.distplot,'BMI_change', kde=True).add_legend()
# Out:
# c:\users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
diet_one = BMI_change[Diet==0]
diet_two = BMI_change[Diet==1]
diet_three = BMI_change[Diet==2]

# %% [markdown]
# ### Run Shapiro Wilks Test

# %%
ss.shapiro(diet_one)
# Out:
# ShapiroResult(statistic=0.9227969646453857, pvalue=0.06736458837985992)

# %%
ss.shapiro(diet_two)
# Out:
# ShapiroResult(statistic=0.9763475060462952, pvalue=0.7722797989845276)

# %%
ss.shapiro(diet_three)
# Out:
# ShapiroResult(statistic=0.9632238149642944, pvalue=0.43632328510284424)

# %% [markdown]
# #### All 3 distributions for the diets in terms of the dependent variable 'BMI_change', have a p-value greater than 0.05. As such, the evidence suggests that all 3 groups are normally distributed

# %% [markdown]
# ## Assumption 6: Homogeneity of Variances

# %% [markdown]
# ### Levene's Test for Homogeneity - using Levene() from Scipy-stats

# %%
ss.levene(
    BMI_change[Diet==0],
    BMI_change[Diet==1],
    BMI_change[Diet==2]
)
# Out:
# LeveneResult(statistic=1.0043048620443853, pvalue=0.37117119715835095)

# %% [markdown]
# ### When studying the homogeneity of 'BMI_change' amongst the three categories of Diets above are showing a p-value greater than 0.05.
#
# ### Infact, it is much greater at *0.53*.

# %% [markdown]
# ***
#
# # One-way Anova
#
# <br>

# %%
ss.f_oneway(
    BMI_change[Diet==0],
    BMI_change[Diet==1],
    BMI_change[Diet==2]
    )
# Out:
# F_onewayResult(statistic=8.344341031617384, pvalue=0.0005345120426406237)

# %% [markdown]
# ### As we see above, the p-value of 0.003 (*lower than 0.05*) suggests that the mean-values for the three diets in the independent variable are different.

# %% [markdown]
# ***
#
# ## Unequal Variances Welch Anova
#
# <br>

# %%
def welch_anova_np(*args, var_equal=False):
    # https://svn.r-project.org/R/trunk/src/library/stats/R/oneway.test.R
    # translated from R Welch ANOVA (not assuming equal variance)

    F_onewayResult = co.namedtuple('F_onewayResult', ('statistic', 'pvalue'))

    args = [np.asarray(arg, dtype=float) for arg in args]
    k = len(args)
    ni = np.array([len(arg) for arg in args])
    mi = np.array([np.mean(arg) for arg in args])
    vi = np.array([np.var(arg,ddof=1) for arg in args])
    wi = ni/vi

    tmp =sum((1-wi/sum(wi))**2 / (ni-1))
    tmp /= (k**2 -1)

    dfbn = k - 1
    dfwn = 1 / (3 * tmp)

    m = sum(mi*wi) / sum(wi)
    f = sum(wi * (mi - m)**2) /((dfbn) * (1 + 2 * (dfbn - 1) * tmp))
    prob = spec.fdtrc(dfbn, dfwn, f)   # equivalent to stats.f.sf
    return F_onewayResult(f, prob)

# %%
# Perform the test.
welch_anova_np(
    BMI_change[Diet==0],
    BMI_change[Diet==1],
    BMI_change[Diet==2]
)
# Out:
# F_onewayResult(statistic=7.497471261642536, pvalue=0.0014240568918744995)

# %% [markdown]
# ### The p-value obtained from this Anova test of different variances is 0.00445 - this is significantly below the threshold of 0.05.
#
# ### The conclusion here is that the mean-weight lost by people who tried out diets 1, 2 and 3 over 6 weeks, **are different.**
